# %% [markdown]
# SHETH L.U.J & SIR M.V COLLEGE
#
# Vedant Patil | T101
#
# Practical No. 2
#
# Aim: Data Frames and Basic Data Pre-processing
#
#
#
#
# *  Read data from CSV and JSON files into a data frame.
# *   Perform basic data pre-processing tasks such as handling missing values and outliers.
#
#
# *   Manipulate and transform data using functions like filtering, sorting, and grouping.

# %% [markdown]
# 2.1 Loading a Sample Dataset

# %%
# load scikit-learn's datasets
from sklearn import datasets

# load digits dataset
digits = datasets.load_digits()

# create features matrix
features = digits.data

# create target vector
target = digits.target

# view first observation
features[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %% [markdown]
# 2.2 Creating a Simulated Dataset

# %%
# load library
from sklearn.datasets import make_regression

# generate features matrix, target vector, and the true coefficients
features, target, coefficients = make_regression(n_samples = 100,
                                                 n_features = 3,
                                                 n_informative = 3,
                                                 n_targets = 1,
                                                 noise = 0.0,
                                                 coef = True,
                                                 random_state = 1)

# view feature matrix and target vector
print("Feature Matrix \n {}".format(features[:3]))
print("Target Vector \n {}".format(target[:3]))
# Out:
# Feature Matrix
#  [[ 1.29322588 -0.61736206 -0.11044703]
#  [-2.793085    0.36633201  1.93752881]
#  [ 0.80186103 -0.18656977  0.0465673 ]]
# Target Vector
#  [-10.37865986  25.5124503   19.67705609]

# %%
# load library
from sklearn.datasets import make_classification

# generate features matrix and target vector
features, target = make_classification(n_samples = 100,
                                       n_features = 3,
                                       n_informative = 3,
                                       n_redundant = 0,
                                       n_classes = 2,
                                       weights = [.25, .75],
                                       random_state = 1)

# view feature matrix and target vector
print("Feature matrix\n {}".format(features[:3]))
print("Target vector\n {}".format(target[:3]))
# Out:
# Feature matrix
#  [[ 1.06354768 -1.42632219  1.02163151]
#  [ 0.23156977  1.49535261  0.33251578]
#  [ 0.15972951  0.83533515 -0.40869554]]
# Target vector
#  [1 0 0]

# %%
# load library
from sklearn.datasets import make_blobs

# generate feature_matrix and target vector
features, target = make_blobs(n_samples = 100,
                              n_features = 2,
                              centers = 3,
                              cluster_std = 0.5,
                              shuffle = True,
                              random_state = 1)

# view feature matrix and target vector
print("Feature Matrix\n {}".format(features[:3]))
print("Target Vector\n {}".format(target[:3]))
# Out:
# Feature Matrix
#  [[ -1.22685609   3.25572052]
#  [ -9.57463218  -4.38310652]
#  [-10.71976941  -4.20558148]]
# Target Vector
#  [0 1 1]

# %%
# load library
import matplotlib.pyplot as plt

# view scatterplot
plt.scatter(features[:,0], features[:,1], c=target)
plt.show()

# %% [markdown]
# 2.3 Loading a CSV File

# %%
# load library
import pandas as pd

# load data
df = pd.read_csv('/content/winequality_red.csv')

df.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5

# %% [markdown]
# 2.4 Loading an Excel File

# %%
# load library
import pandas as pd

# load data from your Excel file, e.g., 'winequality_red.xlsx'
df = pd.read_excel('/content/Covid Dashboard.xlsx', sheet_name=0, header=0)

# show first two rows
df.head(2)
# Out:
#              State/UTs   Zone  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar  South         7670       7        7534     129
# 1       Andhra Pradesh  South      2069770    3128     2052230   14412
#
#    Active Ratio  Discharge Ratio  Discharge Avg  Death Ratio      Death Avg  \
# 0          0.09            98.23  Below Average         1.68  Above Average
# 1          0.15            99.15  Above Average         0.70  Below Average
#
#    Population
# 0      399001
# 1    91702478

# %% [markdown]
# 2.5 Loading a JSON File

# %%
# load library
import pandas as pd

# load data from your JSON file, e.g., '/content/people.json'
df = pd.read_json('/content/people.json', orient="columns")

# show first two rows
df.head(2)
# Out:
#            name                     email             city                mac  \
# 0  Keeley Bosco  katlyn@jenkinsmaggio.net  Lake Gladysberg  08:fd:0b:cd:77:f7
# 1   Rubye Jerde     juvenal@johnston.name             None  90:4d:fa:42:63:a2
#
#                   timestamp           creditcard
# 0 2015-04-25 13:57:36+07:00  1228-1221-1221-1431
# 1 2015-04-25 09:02:04+07:00  1228-1221-1221-1431

# %% [markdown]
# 2.6 Querying a SQL Database

# %%
import pandas as pd
import sqlite3

con=sqlite3.connect("sqlite-sakila.db")
df = pd.read_sql_query("SELECT * FROM actor", con)
df.head()
# Out:
#    actor_id first_name     last_name          last_update
# 0         1   PENELOPE       GUINESS  2021-03-06 15:51:59
# 1         2       NICK      WAHLBERG  2021-03-06 15:51:59
# 2         3         ED         CHASE  2021-03-06 15:51:59
# 3         4   JENNIFER         DAVIS  2021-03-06 15:51:59
# 4         5     JOHNNY  LOLLOBRIGIDA  2021-03-06 15:51:59
